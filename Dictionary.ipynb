# %% [markdown]
# <a href="https://colab.research.google.com/github/mawawazir/Python_Practice/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dictionary :-
# A collection of key value-pairs.

#Create dictionary: Dictionaries are written with curly brackets &  have ky and values.
thisdict={
    "Brand":"Ford",
    "Model":"Mustang",
    "year":1984
}
print(thisdict["Model"])

#Properties:-

#1:- ordered:-
              #Dictionaries don't support index-based access.
print(thisdict["Brand"])


#2:- Mutable:-
              #Means we can change the dictionary after creating it.



#3:- Keys must be unique:-
              #A dictionary cannot have two enteries with the same key.
              #Don't allow duplicates.
print(thisdict)

# Lenght of dictionary:-
print(len(thisdict))

# Dictionary data type:
# the values in dictionary items can be of ay data type.

thisdict1 = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

print(thisdict1)

#type():
print(type(thisdict1))
# Out:
# Mustang
# Ford
# {'Brand': 'Ford', 'Model': 'Mustang', 'year': 1984}
# 3
# {'brand': 'Ford', 'electric': False, 'year': 1964, 'colors': ['red', 'white', 'blue']}
# <class 'dict'>

# %%
#Access items:-
thisdict={
    "Brand":"Ford",
    "Model":"Mustang",
    "year":1984
}
print(thisdict["Brand"])

#.get()
x=thisdict.get("Model",)
print(x)
#keys()
print(thisdict.keys())

#values()

print(thisdict.values())

#items()
print(thisdict.items())
# Out:
# Ford
# Mustang
# dict_keys(['Brand', 'Model', 'year'])
# dict_values(['Ford', 'Mustang', 1984])
# dict_items([('Brand', 'Ford'), ('Model', 'Mustang'), ('year', 1984)])

# %%
#change values:-
thisdict={
    "Brand":"Ford",
    "Model":"Mustang",
    "year":1984
}

thisdict["Brand"]="corolla"
print(thisdict)

thisdict.update({"year":2010})
# Out:
# {'Brand': 'corolla', 'Model': 'Mustang', 'year': 1984}

# %%
#Add items:-
thisdict={
    "Brand":"Ford",
    "Model":"Mustang",
    "year":1984
}
thisdict["color"]="red"
print(thisdict)

thisdict.update({"name":"Gul_khan_"})
print(thisdict)
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'year': 1984, 'color': 'red'}
# {'Brand': 'Ford', 'Model': 'Mustang', 'year': 1984, 'color': 'red', 'name': 'Gul_khan_'}

# %%
#Remove dict items:-
thisdict={
    "Brand":"Ford",
    "Model":"Mustang",
    "year":1984,
    "color":"red"
}
thisdict.pop("Model")
print(thisdict)

thisdict.popitem()
print(thisdict)

#del():-
del thisdict["Brand"]
print(thisdict)

#clear():-
thisdict.clear()
print(thisdict)


#items:-
# Out:
# {'Brand': 'Ford', 'year': 1984, 'color': 'red'}
# {'Brand': 'Ford', 'year': 1984}
# {'year': 1984}
# {}

# %%
#Loop throgh a dictioary:-
thisdict={
    "Brand":"Ford",
    "Model":"Mustang",
    "year":1984,
    "color":"red"
}
for x in thisdict:
  print(x)
# Out:
# Brand
# Brand
# Model
# year
# color
# Ford
# Mustang
# 1984
# red
# Model
# Brand
# Model
# year
# color
# Ford
# Mustang
# 1984
# red
# year
# Brand
# Model
# year
# color
# Ford
# Mustang
# 1984
# red
# color
# Brand
# Model
# year
# color
# Ford
# Mustang
# 1984
# red
# Brand Ford
# Model Mustang
# year 1984
# color red

# %%
  #keys():-
  for x in thisdict.keys():
   print(x)
# Out:
# Brand
# Model
# year
# color

# %%
#values():-
for x in thisdict.values():
    print(x)
# Out:
# Ford
# Mustang
# 1984
# red

# %%
  #items:-
for x, y in thisdict.items():
   print(x, y)
# Out:
# Brand Ford
# Model Mustang
# year 1984
# color red

# %%
#copy dictionary:-
mydict = thisdict.copy()
print(mydict)
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'year': 1984, 'color': 'red'}

# %%
#Dict():-
mydict = dict(thisdict)
print(mydict)
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'year': 1984, 'color': 'red'}

# %%
# Nested Dictionaries
# A dictionary can contain dictionaries, this is called nested dictionaries.

#Eamples:-
myfamily={
  "child1":  {
      "name":"Emil",
      "year":2014
  },
  "child2":{
      "name":"tobis",
      "year":2015
  },
  "child3":{
      "name":"linus",
      "year":2016

  }
}
print(myfamily)
print(myfamily['child1'])
# Out:
# {'child1': {'name': 'Emil', 'year': 2014}, 'child2': {'name': 'tobis', 'year': 2015}, 'child3': {'name': 'linus', 'year': 2016}}
# {'name': 'Emil', 'year': 2014}

# %%
# if we ant to add three dictonaries into a new dictionary.
child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}

print(myfamily)
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}

# %%
# Access items in Nested dictionaries.
print(myfamily["child1"]["name"])
# Out:
# Emil

# %%
#Loop Through Nested Dictionaries
for x, obj in myfamily.items():
  print(x)

  for y in obj:
    print(y + ':', obj[y])
# Out:
# child1
# name: Emil
# year: 2004
# child2
# name: Tobias
# year: 2007
# child3
# name: Linus
# year: 2011
